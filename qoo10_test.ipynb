# %% [markdown]
# # Example 1: Query a table with SQL and magic commands

# %%
# Running this code will query a table in BigQuery and download
# the results to a Pandas DataFrame named `results`.
# Learn more here: https://cloud.google.com/bigquery/docs/visualize-jupyter

# %%bigquery results --project jc-gcp-project
SELECT * FROM `jc-gcp-project.qoo10.product_data_sample` #this table name was set based on the table you chose to query
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# You can view the resulting Pandas DataFrame and work with using the Pandas library.
# https://pandas.pydata.org/docs/getting_started/index.html#getting-started
results
# Out:
#    branch  prod_level  product_id  \
# 0      QT           1   851268185
# 1      QT           1   938291189
# 2      QT           1   938310068
# 3      QT           1   804837897
# 4      QT           1   646155701
# ..    ...         ...         ...
# 95     QT           1   559714920
# 96     QT           1   579314540
# 97     QT           1   614539325
# 98     QT           1   671689477
# 99     QT           1   587901888
#
#                                            product_nm product_sub_nm  \
# 0   소금 스타일 양털-얇게 썬 가을과 겨울 새로운 후드 스웨트 셔츠 여성의 한국 스타일...           None
# 1   롱 패딩패딩 솜옷 라지 사이즈 여자 겨울 롱 와이드 이불 두꺼운 솜옷 캐주얼 한국판...           None
# 2               숏 스웨터오리 자카드 라운드 니트 상의녀 2023 가을 겨울 신상품           None
# 3            부드러운 여성가디건 인조 밍크 스웨터 코트 브이넥 V넥 쇼트 니트 카디건           None
# 4                                         다이어트 클렌즈 주스           None
# ..                                                ...            ...
# ...

# %% [markdown]
# # Example 2: Query a table with BigQuery DataFrames

# %%
# With BigQuery DataFrames, you can use many familiar Pandas methods, but the
# processing happens BigQuery rather than the runtime, allowing you to work with larger
# DataFrames that would otherwise not fit in the runtime memory.
# Learn more here: https://cloud.google.com/python/docs/reference/bigframes/latest

import bigframes.pandas as bf

bf.options.bigquery.location = "US" #this variable is set based on the dataset you chose to query
bf.options.bigquery.project = "jc-gcp-project" #this variable is set based on the dataset you chose to query

# %%
df = bf.read_gbq("jc-gcp-project.qoo10.product_data_sample") #this variable is set based on the dataset you chose to query

# %%
# BigFrames can work with tables that are too large to fit in the notebook memory.
# Look at the first 20 rows.
df.head(20)

# %%
# from google.cloud import storage
# import requests

# def upload_gcs(bucket_name, source_url, destination_name):
#     """GCS에 이미지 업로드"""
#     storage_client = storage.Client()
#     bucket = storage_client.bucket(bucket_name)
#     blob = bucket.blob(destination_name)
#     image_data = requests.get(source_url).content
#     blob.upload_from_string(image_data, content_type="image/jpg")

# # 예시 URL (주어진 URL 사용)
# image_url = "https://gd.image-gmkt.com/li/797/834/699834797.jpg"

# # GCS 버킷 이름 및 저장할 객체 이름 설정
# bucket_name = "jc-gcp-project-01"
# destination_name = "uploaded_image.jpg"

# upload_gcs(bucket_name, image_url, destination_name)

# %%
import requests
from google.cloud import storage

def upload_blob(bucket_name, source_url, destination_blob_name):
    """GCS에 이미지 업로드 (이미지 다운로드 후 업로드)"""

    # 이미지 다운로드
    response = requests.get(source_url)
    response.raise_for_status()  # 다운로드 실패 시 예외 발생
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    # 다운로드한 이미지 데이터 업로드
    blob.upload_from_string(
        response.content, content_type=response.headers['Content-Type']
    )

# 예시 URL (주어진 URL 사용)
image_url = "https://img2.tmon.kr/cdn4/deals/2024/05/22/26762646202/26762646202_front_SZxrV9NpQ7.jpg"

# GCS 버킷 이름 및 저장할 객체 이름 설정
bucket_name = "jc-gcp-project-01"
destination_blob_name = "uploaded_image1.jpg"

upload_blob(bucket_name, image_url, destination_blob_name)

# %%
import requests
from google.cloud import storage

def upload_blob(bucket_name, source_url, destination_blob_name):
    """GCS에 이미지 업로드 (이미지 다운로드 후 업로드)"""

    # 이미지 다운로드
    response = requests.get(source_url)
    response.raise_for_status()  # 다운로드 실패 시 예외 발생
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    # 다운로드한 이미지 데이터 업로드
    blob.upload_from_string(
        response.content, content_type=response.headers['Content-Type']
    )

# 예시 URL (주어진 URL 사용)
image_url = "https://gd.image-gmkt.com/li/797/834/699834797.jpg"

# GCS 버킷 이름 및 저장할 객체 이름 설정
bucket_name = "jc-gcp-project-01"
destination_blob_name = "uploaded_image1.jpg"

upload_blob(bucket_name, image_url, destination_blob_name)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-36-bc109f0baaf9> in <cell line: 26>()
#      24 destination_blob_name = "uploaded_image1.jpg"
#      25
# ---> 26 upload_blob(bucket_name, image_url, destination_blob_name)
#
# <ipython-input-36-bc109f0baaf9> in upload_blob(bucket_name, source_url, destination_blob_name)
#       7     # 이미지 다운로드
#       8     response = requests.get(source_url)
# ----> 9     response.raise_for_status()  # 다운로드 실패 시 예외 발생
#      10     storage_client = storage.Client()
#      11     bucket = storage_client.bucket(bucket_name)
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# ...
